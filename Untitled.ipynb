# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

#pic source = https://www.twodots.one/
#https://scikit-learn.org/stable/modules/svm.html
#https://www.pyimagesearch.com/2014/05/26/opencv-python-k-means-color-clustering/
#https://stackoverflow.com/questions/55924828/how-to-create-a-closed-region-around-cluster-of-pixels

# %%
pic = imageio.imread('C:/Users/yuilunyu2/Downloads/two-dots-logo.png')

# %%
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(pic)

# %%
print('Type of image:', type(pic), "\n")
print('Shape of image:', pic.shape)

width, length, dimension, size = pic.shape[0], pic.shape[1], pic.ndim, pic.size
print('Width of image:', width, '\nLength of image:', length, '\nDimension of image:', dimension, '\nImage size:', size, '\n')

center = (width/2, length/2)
print(center)
# Out:
# Type of image: <class 'imageio.core.util.Array'>
#
# Shape of image: (574, 1420, 4)
# Width of image: 574
# Length of image: 1420
# Dimension of image: 3
# Image size: 3260320
#
# (287.0, 710.0)

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(width))
plt.xlabel('Width {}'.format(length))
plt.imshow(pic[:,:,2])
plt.show()
